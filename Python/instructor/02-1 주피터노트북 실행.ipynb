# %% [markdown]
# ## 기본 단축키

# %% [markdown]
# - Shift + Enter – 셀 실행 후 아래 셀 이동 (없으면 생성)
# - Alt + Enter - 셀 실행 후 새로운 셀 추가
# - Ctrl + Enter – 셀 실행
# - Ctrl + S - 노트북 저장
# - Ctrl + H – 찾기 및 바꾸기 (다음 찾기 F3, 이전 찾기 Shift + F3)
# - Enter - 입력모드로 전환
# - Esc - 입력모드에서 명령모드로 전환
# - D – 셀 삭제
# - M - 셀 타입 변경(마크다운)
# - Y - 셀 타입 변경(코드)
# - X – 셀 잘라내기 (명령모드)
# - C – 셀 복사하기 (명령모드)
# - V – 셀 붙여넣기 (명령모드)
# - Ctrl + / - 선택된 코드 주석처리

# %% [markdown]
# ## Jupyter Notebook Test
#
# - 주피터 처음 실행해보기
# - 주피터의 기본기능 익혀보기

# %%
print('Hello World')
print('저는 송은채입니다')
# Out:
# Hello World
# 저는 송은채입니다

# %% [markdown]
# ### 그래프 그려보기

# %%
! pip install numpy matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\selena\anaconda3\envs\sesac\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
# 간단한 선 그래프 그리기
x_values = [1, 2, 3, 4]  # x값으로 사용할 리스트
y_values = [1, 2, 3, 4]  # y값으로 사용할 리스트

plt.plot(x_values, y_values)  # x값과 y값을 플로팅
plt.xlabel('Index')           # x축 레이블을 'Index'로 설정
plt.ylabel('Number')          # y축 레이블을 'Number'로 설정
plt.title('Simple Line Plot') # 그래프 제목 추가
plt.show()                    # 그래프를 화면에 표시
